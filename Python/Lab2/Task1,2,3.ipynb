# %%
import pandas as pd

# %% [markdown]
# **Task1**

# %%
bank = pd.read_csv("banklist.csv")

# %%
##1
bank.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
##2
bank.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
##3
bank['ST'].nunique()
# Out:
# 44

# %%
##4
list(bank['ST'].unique())
# Out:
# ['IL',
#  'WI',
#  'LA',
#  'UT',
#  'NJ',
#  'AR',
#  'GA',
#  'PA',
#  'TN',
#  'WA',
#  'CO',
#  'PR',
#  'FL',
#  'MN',
#  'CA',
#  'MD',
#  'OK',
#  'OH',
#  'SC',
#  'VA',
#  'ID',
#  'TX',
#  'CT',
#  'AZ',
#  'NV',
#  'NC',
#  'KY',
#  'MO',
#  'KS',
#  'AL',
#  'MI',
#  'IN',
#  'IA',
#  'NE',
#  'MS',
#  'NM',
#  'OR',
#  'NY',
#  'MA',
#  'SD',
#  'WY',
#  'WV',
#  'NH',
#  'HI']

# %%
##5
bank.sort_values('CERT',ascending=True).head(5)['ST']
# Out:
# 6      AR
# 185    GA
# 238    GA
# 87     OK
# 161    WA
# Name: ST, dtype: object

# %%
##6
bank.sort_values('CERT',ascending=False).head(5)['Acquiring Institution']
# Out:
# 50                 Capital Bank, N.A.
# 167                Bank of the Ozarks
# 32                  First Choice Bank
# 207    Peoples Bank of East Tennessee
# 304              Wheaton Bank & Trust
# Name: Acquiring Institution, dtype: object

# %%
##7
bank[bank['Acquiring Institution'] =='State Bank of Texas'].shape[0]
# Out:
# 3

# %%
##8
bank[(bank['Acquiring Institution'] =='State Bank of Texas') & (bank['ST'] =='TX')]
# Out:
#                           Bank Name    City  ST   CERT Acquiring Institution  \
# 450  Millennium State Bank of Texas  Dallas  TX  57667   State Bank of Texas
#
#     Closing Date Updated Date
# 450     2-Jul-09    26-Oct-12

# %%
##9
bank[(bank['ST'] =='CA')].value_counts("City").head(1)
# Out:
# City
# Los Angeles    4
# Name: count, dtype: int64

# %%
##10
i = 0
for name in bank['Bank Name']:
    if 'Bank' not in name:
      i = i+1

print(f"count: ", i)
# Out:
# count:  14

# %%
##11
i = 0
for name in bank['Bank Name']:
  for index,char in enumerate(name):
    if char == 'S'and index == 0:
      i = i+1
print(f"count: ", i)
# Out:
# count:  53

# %%
##12
print(f"Count: ",bank[bank['CERT'] >= 20000].shape[0])
# Out:
# Count:  417

# %% [markdown]
# Task **2**

# %%
apps_df = pd.read_csv("google-play-store.csv")

# %%
##1

# %%
list(apps_df.sort_values('min_installs',ascending=False).head(5)['genre'].unique())[0]
# Out:
# 'Communication'

# %%
##2

# %%
list(apps_df[apps_df['min_installs'] == 0]['genre'].unique())[0]
# Out:
# 'Simulation'

# %%
##3

# %%
apps_df.sort_values('min_installs',ascending=False).head(5)['genre'].head(1)
# Out:
# 20761    Communication
# Name: genre, dtype: object

# %%
##4

# %%
apps_df['min_installs'].mean()
# Out:
# 2035663.3054997288

# %%
###6

# %%
apps_df.groupby('genre')['ratings'].mean()
# Out:
# genre
# Action                     196421.164271
# Adventure                   82928.460039
# Arcade                     167421.695556
# Art & Design                 5965.229665
# Auto & Vehicles              3441.716028
# Beauty                       3303.308943
# Board                       40307.981788
# Books & Reference            9960.886959
# Business                     5816.281929
# Card                        39052.077042
# Casino                      67599.412621
# Casual                     154775.523124
# Comics                      18852.913295
# Communication              254248.665579
# Dating                      27304.040816
# Education                    4577.406114
# Educational                  9691.621795
# Entertainment               24828.777909
# Events                        897.717647
# Finance                     11518.936932
# Food & Drink                 7182.864227
# Health & Fitness            12486.677482
# House & Home                11572.583333
# ...

# %%
## 7

# %%
apps_df.sort_values('reviews',ascending=False).head(5)
# Out:
#                            app_id                                     title  \
# 5298          com.facebook.katana                                  Facebook
# 7119        com.instagram.android                                 Instagram
# 5058                 com.whatsapp                        WhatsApp Messenger
# 12054  com.supercell.clashofclans                            Clash of Clans
# 5293            com.facebook.orca  Messenger – Text and Video Chat for Free
#
#           reviews     ratings  min_installs     score  offers_iap  \
# 5298   22053770.0  81284862.0    1000000000  4.073720        True
# 7119   21702496.0  71203510.0    1000000000  4.516777       False
# 5058   19031005.0  75031471.0    1000000000  4.408304       False
# 12054  17895834.0  46411254.0     100000000  4.603980        True
# 5293   15404150.0  59965894.0    1000000000  4.059807        True
#
#        ad_supported    released  ratings_per_day          genre  \
# ...

# %%
### 8

# %%
apps_df[apps_df['offers_iap'] == True].count().shape[0]
# Out:
# 18

# %%
## 9

# %%
apps_df.groupby('genre')['ratings'].count()
# Out:
# genre
# Action                      974
# Adventure                   513
# Arcade                      900
# Art & Design                418
# Auto & Vehicles             574
# Beauty                      123
# Board                       604
# Books & Reference          3052
# Business                   2717
# Card                        649
# Casino                      412
# Casual                     1319
# Comics                      173
# Communication              1226
# Dating                      147
# Education                  6673
# Educational                 936
# Entertainment              3395
# Events                       85
# Finance                    1982
# Food & Drink                847
# Health & Fitness           2558
# House & Home                240
# Libraries & Demo             78
# Lifestyle                  2797
# Maps & Navigation           893
# Medical                    1329
# Music                       219
# Music & Audio              2443
# ...

# %%
## 10

# %%
head_df = apps_df.sort_values('released', ascending= True).head(1)
tail_df = apps_df.sort_values('released', ascending= False).head(1)
print(head_df['released'])
print(tail_df['released'])
# Out:
# 7548    2010-01-28
# Name: released, dtype: object
# 54397    2018-11-12
# Name: released, dtype: object

# %%
##11
avg=apps_df[(apps_df['reviews']>10000)==True]
avg.groupby('title')['ratings'].mean()
# Out:
# title
# "Memory" - Memory game                                 86293.0
# #1 GK App: Daily Current Affairs 2018, GK in Hindi     32290.0
# #1 Vocab App: Editorial, Quiz, Grammar, Dictionary     51837.0
# +Download 4 Instagram Twitter                          46866.0
# 1,000,000 Wallpapers HD 4k(Best Theme App)            235579.0
#                                                         ...
# 🏒Puppet Ice Hockey: Pond Head 🏆                        73397.0
# 👗 Sophie Fashionista - Dress Up Game                   70633.0
# 🔎 Hidden Objects: Twilight Town                        54904.0
# 🔥Efectum – Slow Motion, Reverse Cam, Fast Video        38885.0
# 🥇 Family Locator - Phone Tracker                       43590.0
# Name: ratings, Length: 6393, dtype: float64

# %%
## 12

# %%
apps_df.groupby("title")["score"].sum().head(3)
# Out:
# title
# "Memory" - Memory game                                4.144554
# "Memory" - Memory game (NoAds)                        4.657143
# #1 GK App: Daily Current Affairs 2018, GK in Hindi    4.627346
# Name: score, dtype: float64

# %%
## 13

# %%
per_app=apps_df[(apps_df['ad_supported']==True)]
per_app=per_app[(per_app['offers_iap']==True)]
((per_app['title'].count())/(apps_df['title'].count()))*100
# Out:
# 16.963345774715282

# %%
## 14

# %%
apps_df['released'].value_counts().head(1)
# Out:
# released
# 2018-09-26    131
# Name: count, dtype: int64

# %%
## 15
rev=apps_df.groupby('genre')['reviews'].sum()
rat=apps_df.groupby('genre')['ratings'].mean()
rat.corr(rev)
# Out:
# 0.7473927439237391

# %%
## 16

# %%
temp=apps_df
temp.insert(4, 'Crating×weight', temp['ratings']*temp['reviews'])
temp=temp.groupby('genre')[['Crating×weight','reviews']].sum()
temp['Crating×weight']/temp['reviews']
# Out:
# genre
# Action                     3.881101e+06
# Adventure                  4.107444e+06
# Arcade                     7.456326e+06
# Art & Design               1.557658e+05
# Auto & Vehicles            1.254883e+05
# Beauty                     3.435117e+04
# Board                      7.701927e+05
# Books & Reference          7.915964e+05
# Business                   4.576586e+05
# Card                       6.914190e+05
# Casino                     6.315197e+05
# Casual                     6.926626e+06
# Comics                     4.779676e+05
# Communication              3.257192e+07
# Dating                     1.856416e+05
# Education                  1.742543e+06
# Educational                2.735333e+05
# Entertainment              2.189184e+06
# Events                     5.594167e+03
# Finance                    4.322802e+05
# Food & Drink               3.192776e+05
# Health & Fitness           8.667980e+05
# House & Home               2.874406e+05
# ...

# %%
## 17

# %%
cleaned_data = apps_df.dropna()
cleaned_data['reviews'] = cleaned_data['reviews'].replace(0, 1)
cleaned_data['sting/weight'] = cleaned_data['ratings'] / cleaned_data['reviews']
grouped_data = cleaned_data.groupby(['genre', 'title'])['sting/weight'].max()
top_4_apps = grouped_data.sort_values(ascending=False).head(4)
top_4_apps
# Out:
# <ipython-input-82-47b56fc1ab88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['reviews'] = cleaned_data['reviews'].replace(0, 1)
# <ipython-input-82-47b56fc1ab88>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['sting/weight'] = cleaned_data['ratings'] / cleaned_data['reviews']
# genre              title
# Simulation         Blood Sugar Diary                                    85.0
# Entertainment      주현미 노래듣기 - 7080 트로트 메들리                              77.0
# ...

# %% [markdown]
# **Task 3**

# %%
apps_df = pd.read_csv('google-play-store.csv')

# %%
### 1
plt1 = apps_df.genre.value_counts().plot(kind='bar')
plt.title('count of apps in each genre')
plt1.set(xlabel = 'genre', ylabel='number of apps')
# Out:
# [Text(0.5, 0, 'genre'), Text(0, 0.5, 'number of apps')]

# %%
### 3
plt2 = plt.scatter(x = apps_df.min_installs, y = apps_df.reviews, c ="blue")
plt.show()

# %%
### 7
ad_supported_counts = apps_df['ad_supported'].value_counts()

labels = ad_supported_counts.index
sizes = ad_supported_counts.values
plt.figure(figsize=(4, 4))
plt.pie(sizes, labels=labels)
plt.title('Proportion of Apps that are Ad-Supported vs Not Ad-Supported')

plt.show()
